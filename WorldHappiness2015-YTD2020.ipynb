# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
YR2005_2019=pd.read_csv('2005-2019.csv')

# %%
YR2005_2019
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
YR2005_2019.drop(['GINI index (World Bank estimate)', 
                 'GINI index (World Bank estimate), average 2000-2017, unbalanced panel', 'gini of household income reported in Gallup, by wp5-year',
                 'Most people can be trusted, Gallup', 'Most people can be trusted, WVS round 1981-1984',
                 'Most people can be trusted, WVS round 1989-1993', 'Most people can be trusted, WVS round 1994-1998' , 
                 'Most people can be trusted, WVS round 1999-2004' ,
                 'Most people can be trusted, WVS round 2010-2014'], axis=1, inplace=True)
YR2005_2019
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
YR2005_2019.drop(['Standard deviation of ladder by country-year', 
                 'Standard deviation/Mean of ladder by country-year', 'Most people can be trusted, WVS round 2005-2009'], axis=1, inplace=True)
YR2005_2019
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
YR2019 = YR2005_2019.loc[YR2005_2019["year"] == 2019]
YR2019
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 11    Afghanistan  2019     2.375092            7.458469        0.419973
# 23        Albania  2019     4.995318            9.456569        0.686365
# 31        Algeria  2019     4.744627            9.537369        0.803259
# 49      Argentina  2019     6.085561            9.772140        0.896371
# 75      Australia  2019     7.233995           10.725492        0.942774
# ...           ...   ...          ...                 ...             ...
# 1794    Venezuela  2019     5.080803                 NaN        0.887672
# 1808      Vietnam  2019     5.467451            8.850640        0.847592
# 1820        Yemen  2019     4.196913                 NaN        0.870043
# 1833       Zambia  2019     3.306797            8.224403        0.637894
# 1847     Zimbabwe  2019     2.693523            7.850442        0.759162
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
YR2005_2018 = YR2005_2019.loc[YR2005_2019["year"] != 2019]
YR2005_2018
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.144916        0.450662
# 1     Afghanistan  2009     4.401778            7.314788        0.552308
# 2     Afghanistan  2010     4.758381            7.421525        0.539075
# 3     Afghanistan  2011     3.831719            7.394349        0.521104
# 4     Afghanistan  2012     3.782938            7.480296        0.520637
# ...           ...   ...          ...                 ...             ...
# 1842     Zimbabwe  2014     4.184451            7.826639        0.765839
# 1843     Zimbabwe  2015     3.703191            7.827643        0.735800
# 1844     Zimbabwe  2016     3.735400            7.819675        0.768425
# 1845     Zimbabwe  2017     3.638300            7.851042        0.754147
# 1846     Zimbabwe  2018     3.616480            7.896704        0.775388
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
YR2019.to_csv("YR2019.csv", encoding='utf-8', index=False)
YR2005_2018.to_csv("YR2005_2018.csv", encoding='utf-8', index=False)

# %% [markdown]
# #machine learning

# %%
from sklearn.linear_model import LinearRegression
YR2005_2018 = LinearRegression()
YR2005_2018
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X = YR2005_2018[["Life Ladder", "Social support"]]
y = YR2005_2018["Log GDP per capita"].values.reshape(-1, 1)
print(X.shape, y.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-8aa8f7762f17> in <module>
# ----> 1 YR2005_2018.fit(X, y)
#       2 print(YR2005_2018)
#
# NameError: name 'X' is not defined
